# %%
import deepchem as dc
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# /Users/reid/py/deepchemBenchmark/.venv/lib/python3.13/site-packages/deepchem/models/torch_models/layers.py:1207: SyntaxWarning: invalid escape sequence '\m'
#   Input node features of shape :math:`(|\mathcal{V}|, F_n)`
# /Users/reid/py/deepchemBenchmark/.venv/lib/python3.13/site-packages/deepchem/models/torch_models/attention.py:64: SyntaxWarning: invalid escape sequence '\i'
# ...

# %%
tasks, datasets, transformers = dc.molnet.load_qm9()
train_dataset, valid_dataset, test_dataset = datasets
# Out:
# [14:54:08] Explicit valence for atom # 1 C, 5, is greater than permitted
# [14:54:08] ERROR: Could not sanitize molecule ending on line 2704
# [14:54:08] ERROR: Explicit valence for atom # 1 C, 5, is greater than permitted
# [14:54:08] Explicit valence for atom # 1 C, 5, is greater than permitted
# [14:54:08] ERROR: Could not sanitize molecule ending on line 9097
# [14:54:08] ERROR: Explicit valence for atom # 1 C, 5, is greater than permitted
# [14:54:08] Explicit valence for atom # 2 C, 5, is greater than permitted
# [14:54:08] ERROR: Could not sanitize molecule ending on line 19803
# [14:54:08] ERROR: Explicit valence for atom # 2 C, 5, is greater than permitted
# [14:54:08] Explicit valence for atom # 2 C, 5, is greater than permitted
# [14:54:08] ERROR: Could not sanitize molecule ending on line 19870
# [14:54:08] ERROR: Explicit valence for atom # 2 C, 5, is greater than permitted
# [14:54:08] Explicit valence for atom # 2 C, 5, is greater than permitted
# ...

# %%
import numpy as np 
from pprint import pprint

# %%
eigen = np.linalg.eig(train_dataset.X[0,:,:])

# %%
eigenvalues = eigen.eigenvalues
len(eigenvalues[eigenvalues > 0])
# Out:
# 20

# %%
train_dataset.get_task_names()
# Out:
# array(['mu', 'alpha', 'homo', 'lumo', 'gap', 'r2', 'zpve', 'cv', 'u0',
#        'u298', 'h298', 'g298'], dtype='<U5')

# %%
datum = {
    "smiles": train_dataset.ids[0],
    # "coloumb_matrix": train_dataset.X[0,:,:],
    "coloumb_matrix_eigenvalues": eigenvalues.tolist(),
    # "coloumb_matrix_eigenvectors": eigen.eigenvectors
}
for i in range(len(train_dataset.get_task_names())):
    datum[train_dataset.get_task_names().tolist()[i]] = train_dataset.y[0][i].item()
pprint(datum)
# Out:
# {'alpha': -0.9035587201768438,
#  'coloumb_matrix_eigenvalues': [(126.83084977958836+0j),
#                                 (53.74594518637688+0j),
#                                 (48.06153426243713+0j),
#                                 (35.08136235570217+0j),
#                                 (31.626069014129996+0j),
#                                 (19.987127053734866+0j),
#                                 (24.899113908084466+0j),
#                                 (23.3229490901241+0j),
#                                 (24.068176452517136+0j),
#                                 (0.5217126600388746+0j),
#                                 (0.33644442119673895+0j),
#                                 (0.29293189136799835+0j),
#                                 (0.2743034041294312+0j),
#                                 (0.1518590447607298+0j),
#                                 (0.22866068161027792+0j),
#                                 (0.16789312534539866+0j),
# ...

# %%
train_dataset.y
# Out:
# array([[-2.41336725e-01, -9.03558720e-01,  5.31246511e-02, ...,
#         -1.22326172e+00, -1.22326172e+00, -1.22327390e+00],
#        [ 8.34475182e-01, -1.47025165e+00, -1.21740386e+00, ...,
#          4.62369191e-01,  4.62369210e-01,  4.62381817e-01],
#        [ 1.25219840e+00, -7.90227135e-04,  2.76865521e-01, ...,
#         -5.83670360e-01, -5.83670364e-01, -5.83680792e-01],
#        ...,
#        [ 3.10596740e+00, -3.60043414e-01,  5.12592508e-01, ...,
#         -9.36345539e-01, -9.36345544e-01, -9.36272469e-01],
#        [ 1.09048782e+00, -1.10288630e+00, -4.82255286e-01, ...,
#         -1.81380174e+00, -1.81380175e+00, -1.81382782e+00],
#        [-2.80105351e-01, -2.89351658e-01,  1.34363002e+00, ...,
#         -4.65976346e-01, -4.65976350e-01, -4.65958852e-01]],
#       shape=(105576, 12))
